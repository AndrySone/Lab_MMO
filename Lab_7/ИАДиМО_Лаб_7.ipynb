# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrySone/Lab_MMO/blob/main/Lab_7/%D0%98%D0%90%D0%94%D0%B8%D0%9C%D0%9E_%D0%9B%D0%B0%D0%B1_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('/content/drive/MyDrive/ИАДиМО/Лаб_7/50_Startups.csv')
dataset.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 4].values
print ("Матрица признаков"); print(X[:5])
print ("Зависимая переменная"); print(y[:5])
# Out:
# Матрица признаков
# [[165349.2 136897.8 471784.1 'New York']
#  [162597.7 151377.59 443898.53 'California']
#  [153441.51 101145.55 407934.54 'Florida']
#  [144372.41 118671.85 383199.62 'New York']
#  [142107.34 91391.77 366168.42 'Florida']]
# Зависимая переменная
# [192261.83 191792.06 191050.39 182901.99 166187.94]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# создаем список трансформеров
transformers = [
    ('imp', SimpleImputer(), [0, 1, 2]),
    ('onehot', OneHotEncoder(), [3])
]

# Создаем объект ColumnTransformer и передаем ему список трансформеров
ct = ColumnTransformer(transformers)

# Выполняем трансформацию признаков
X = ct.fit_transform(X)
print(X.shape)
X
# Out:
# (50, 6)
# array([[1.6534920e+05, 1.3689780e+05, 4.7178410e+05, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [1.6259770e+05, 1.5137759e+05, 4.4389853e+05, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [1.5344151e+05, 1.0114555e+05, 4.0793454e+05, 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.4437241e+05, 1.1867185e+05, 3.8319962e+05, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [1.4210734e+05, 9.1391770e+04, 3.6616842e+05, 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.3187690e+05, 9.9814710e+04, 3.6286136e+05, 0.0000000e+00,
#         0.0000000e+00, 1.0000000e+00],
#        [1.3461546e+05, 1.4719887e+05, 1.2771682e+05, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [1.3029813e+05, 1.4553006e+05, 3.2387668e+05, 0.0000000e+00,
#         1.0000000e+00, 0.0000000e+00],
#        [1.2054252e+05, 1.4871895e+05, 3.1161329e+05, 0.0000000e+00,
# ...

# %%
X = np.delete(X, 3, axis=1)
print(X[:4,:])
# Out:
# [[1.6534920e+05 1.3689780e+05 4.7178410e+05 0.0000000e+00]
#  [1.6259770e+05 1.5137759e+05 4.4389853e+05 1.0000000e+00]
#  [1.5344151e+05 1.0114555e+05 4.0793454e+05 0.0000000e+00]
#  [1.4437241e+05 1.1867185e+05 3.8319962e+05 0.0000000e+00]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [103904.50874716 132759.25370808 133569.91654763  72914.38212352
#  179629.24704261 115168.69730904  67116.14762487  98157.44039793
#  114758.22533246 169065.46632235]

# %%
import statsmodels.api as sm
X = np.append(arr = np.ones((50, 1)).astype(int), values = X, axis = 1)
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):           1.34e-27
# Time:                        10:55:25   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.008e+04   6952.587      7.204      0.000    3.61e+04    6.41e+04
# ...

# %%
X_opt = X[:, [0, 1, 3, 4]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     294.1
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):           5.20e-30
# Time:                        10:55:32   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1067.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         4.7e+04   3043.007     15.446      0.000    4.09e+04    5.31e+04
# ...

# %%
X_opt = X[:, [0, 3, 4, 5]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.562
# Model:                            OLS   Adj. R-squared:                  0.534
# Method:                 Least Squares   F-statistic:                     19.71
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):           2.32e-08
# Time:                        10:56:19   Log-Likelihood:                -579.99
# No. Observations:                  50   AIC:                             1168.
# Df Residuals:                      46   BIC:                             1176.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.284e+04   9503.488      6.612      0.000    4.37e+04     8.2e+04
# ...

# %%
X_opt = X[:, [0, 3, 5]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.561
# Model:                            OLS   Adj. R-squared:                  0.542
# Method:                 Least Squares   F-statistic:                     29.99
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):           4.04e-09
# Time:                        10:56:26   Log-Likelihood:                -580.09
# No. Observations:                  50   AIC:                             1166.
# Df Residuals:                      47   BIC:                             1172.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.052e+04   7859.603      7.700      0.000    4.47e+04    7.63e+04
# ...

# %%
X_opt = X[:, [0, 3]]
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):           4.38e-10
# Time:                        10:56:33   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const           6e+04   7684.530      7.808      0.000    4.46e+04    7.55e+04
# ...
